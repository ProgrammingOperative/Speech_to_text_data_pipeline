# %%
import pandas as pd

# %%
df = pd.read_csv("/mnt/10ac-batch-5/week9/reiten/interim/kafka_set.csv", )
df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0   Id  \
# 0             0         0.0   90
# 1             1         1.0  168
# 2             2         2.0    1
# 3             3         3.0   23
# 4             4         4.0  397
# 5             5         5.0  596
# 6             0         NaN   90
# 7             1         NaN  168
# 8             2         NaN    1
# 9             3         NaN   23
#
#                                                 Text  \
# 0   ቶማስ ባኽ ስፖርትን የፖለቲካ መጠቀሚያ የማድረግ አዝማሚያ እየሰፋ በመጣ...
# 1   ራሱን በመኖርና ባለመኖር መካከል ከቶ በደመነፍስ እንደሚኖር ሰው ቫይረሱ...
# 2  ብርሃን ፈይሳየኢትዮጵያ ቦክስ ፌዴሬሽን በየዓመቱ የሚያዘጋጀው የክለቦች ቻ...
# 3  ስለ ታላላቅ መኪናዎች ግን የክፍሉ ባለሥልጣን የማገጃ ምልክት ቢያደርግበት...
# 4   በወጣት ወንዶች መካከል የሚካሄደው ውድድር ደግሞ ስምንት ኪሎ ሜትር የሚ...
# 5  በእጩነት ያቀረባትን ኦሮሚያ ክልል እንዲሁም ከፕሬዚዳንታዊ ምርጫው ራሳቸው...
# 6   ቶማስ ባኽ ስፖርትን የፖለቲካ መጠቀሚያ የማድረግ አዝማሚያ እየሰፋ በመጣ...
# 7   ራሱን በመኖርና ባለመኖር መካከል ከቶ በደመነፍስ እንደሚኖር ሰው ቫይረሱ...
# 8  ብርሃን ፈይሳየኢትዮጵያ ቦክስ ፌዴሬሽን በየዓመቱ የሚያዘጋጀው የክለቦች ቻ...
# 9  ስለ ታላላቅ መኪናዎች ግን የክፍሉ ባለሥልጣን የማገጃ ምልክት ቢያደርግበት...
#
# ...
